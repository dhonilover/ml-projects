# %% [markdown]
# # Project-1 wine quality red

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("winedataset.csv")
df
# Out:
#     Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0       1    14.23        1.71  2.43               15.6        127
# 1       1    13.20        1.78  2.14               11.2        100
# 2       1    13.16        2.36  2.67               18.6        101
# 3       1    14.37        1.95  2.50               16.8        113
# 4       1    13.24        2.59  2.87               21.0        118
# ..    ...      ...         ...   ...                ...        ...
# 91      2    12.00        1.51  2.42               22.0         86
# 92      2    12.69        1.53  2.26               20.7         80
# 93      2    12.29        2.83  2.22               18.0         88
# 94      2    11.62        1.99  2.28               18.0         98
# 95      2    12.47        1.52  2.20               19.0        162
#
#     Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0            2.80        3.06                  0.28             2.29
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Exploratory data analysis

# %%
# lets do some  basic analysis
df.shape
# Out:
# (96, 14)

# %%
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92         1065
# 1             4.38  1.05           3.40         1050
# ...

# %%
df.describe()
# Out:
#            Class    Alcohol  Malic acid        Ash  Alcalinity of ash  \
# count  96.000000  96.000000   96.000000  96.000000          96.000000
# mean    1.385417  13.240417    1.842917   2.363646          18.018750
# std     0.489248   0.815003    0.732452   0.278080           3.256906
# min     1.000000  11.620000    0.890000   1.360000          10.600000
# 25%     1.000000  12.597500    1.507500   2.227500          16.000000
# 50%     1.000000  13.365000    1.710000   2.360000          17.700000
# 75%     2.000000  13.860000    1.892500   2.560000          19.425000
# max     2.000000  14.830000    4.040000   3.220000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count   96.000000      96.000000   96.000000             96.000000
# mean   102.770833       2.588958    2.560729              0.315000
# std     15.591819       0.541424    0.720746              0.104045
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 96 non-null     int64
#  1   Alcohol               96 non-null     float64
#  2   Malic acid            96 non-null     float64
#  3   Ash                   96 non-null     float64
#  4   Alcalinity of ash     96 non-null     float64
#  5   Magnesium             96 non-null     int64
#  6   Total phenols         96 non-null     float64
#  7   Flavanoids            96 non-null     float64
#  8   Nonflavanoid phenols  96 non-null     float64
#  9   Proanthocyanins       96 non-null     float64
#  10  Color intensity       96 non-null     float64
#  11  Hue                   96 non-null     float64
#  12  diluted wines         96 non-null     float64
#  13  Proline               96 non-null     int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Class',
#  'Alcohol',
#  'Malic acid',
#  'Ash',
#  'Alcalinity of ash',
#  'Magnesium',
#  'Total phenols',
#  'Flavanoids',
#  'Nonflavanoid phenols',
#  'Proanthocyanins',
#  'Color intensity',
#  'Hue',
#  'diluted wines',
#  'Proline    ']

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %% [markdown]
# note - wine dataset has no null values , its a clean dataset

# %% [markdown]
# # lets do some graphical analysis

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# checking for skewness

# %%
df.skew()
# Out:
# Class                   0.478372
# Alcohol                -0.321517
# Malic acid              1.722473
# Ash                    -0.476961
# Alcalinity of ash       0.684215
# Magnesium               0.987880
# Total phenols          -0.298681
# Flavanoids             -0.518829
# Nonflavanoid phenols    0.938683
# Proanthocyanins        -0.003002
# Color intensity         0.346272
# Hue                     0.125022
# diluted wines          -0.608221
# Proline                 0.020672
# dtype: float64

# %% [markdown]
# Note:- as we know acceptable range for skewness is -0.5 to +0.5
#      and some of our columns are exceeding the range so lets remove skewness

# %%
#removing skewness using cuberoot method

df["Malic acid"]=np.cbrt(df["Malic acid"])
df["Alcalinity of ash"]=np.cbrt(df["Alcalinity of ash"])
df["Magnesium"]=np.cbrt(df["Magnesium"])
df["Flavanoids"]=np.cbrt(df["Flavanoids"])
df["Nonflavanoid phenols"]=np.cbrt(df["Nonflavanoid phenols"])
df["diluted wines"]=np.cbrt(df["diluted wines"])

# %%
df.skew()
# Out:
# Class                   0.478372
# Alcohol                -0.321517
# Malic acid              1.029055
# Ash                    -0.476961
# Alcalinity of ash       0.160071
# Magnesium               0.591252
# Total phenols          -0.298681
# Flavanoids             -1.046986
# Nonflavanoid phenols    0.359547
# Proanthocyanins        -0.003002
# Color intensity         0.346272
# Hue                     0.125022
# diluted wines          -0.961208
# Proline                 0.020672
# dtype: float64

# %%
df["Class"].value_counts()
# Out:
# 1    59
# 2    37
# Name: Class, dtype: int64

# %% [markdown]
# # checking corelation

# %%
# visualizing the correlation matrix by plotting heatmap
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot = True, cmap = "Blues_r")

plt.show()

# %%
#checking correlation between features and the target.
cor = df.corr()
cor
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.785514   -0.362809 -0.419728
# Alcohol              -0.785514  1.000000    0.256109  0.259528
# Malic acid           -0.362809  0.256109    1.000000  0.302362
# Ash                  -0.419728  0.259528    0.302362  1.000000
# Alcalinity of ash     0.371189 -0.358536    0.055609  0.382192
# Magnesium            -0.330710  0.296448    0.139202  0.249776
# Total phenols        -0.588980  0.608781    0.138423  0.301533
# Flavanoids           -0.733983  0.701251    0.244011  0.397795
# Nonflavanoid phenols  0.261511 -0.212208    0.020896  0.169673
# Proanthocyanins      -0.331512  0.324355    0.122535  0.140845
# Color intensity      -0.693985  0.718557    0.121852  0.190851
# Hue                   0.270497 -0.183706   -0.352286  0.024406
# diluted wines        -0.501750  0.394890    0.264285  0.273052
# Proline              -0.798018  0.717216    0.134217  0.351090
#
# ...

# %%
cor['Class'].sort_values(ascending=False)
# Out:
# Class                   1.000000
# Alcalinity of ash       0.371189
# Hue                     0.270497
# Nonflavanoid phenols    0.261511
# Magnesium              -0.330710
# Proanthocyanins        -0.331512
# Malic acid             -0.362809
# Ash                    -0.419728
# diluted wines          -0.501750
# Total phenols          -0.588980
# Color intensity        -0.693985
# Flavanoids             -0.733983
# Alcohol                -0.785514
# Proline                -0.798018
# Name: Class, dtype: float64

# %% [markdown]
# Feature Scaling by Standard scalirazation method

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=df.drop("Class",axis=1)
y=df["Class"]

# %%
scaler=StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#      Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0   1.220583   -0.087901  0.239868          -0.732668   1.545995
# 1  -0.049851    0.023986 -0.808471          -2.415477  -0.136344
# 2  -0.099188    0.854248  1.107458           0.239047  -0.068949
# 3   1.393263    0.284006  0.492915          -0.330189   0.707145
# 4  -0.000514    1.145563  1.830450           0.943509   1.014299
# ..       ...         ...       ...                ...        ...
# 91 -1.529968   -0.425421  0.203718           1.221190  -1.130983
# 92 -0.678901   -0.390375 -0.374676           0.858490  -1.590471
# 93 -1.172273    1.431695 -0.519274           0.053552  -0.982585
# 94 -1.998672    0.342972 -0.302376           0.053552  -0.272494
# 95 -0.950256   -0.407860 -0.591573           0.360505   3.402710
#
#     Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0        0.391836    0.687651             -0.257100         0.993767
# ...

# %%
y
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 91    2
# 92    2
# 93    2
# 94    2
# 95    2
# Name: Class, Length: 96, dtype: int64

# %% [markdown]
# # Lets Check Variance Inflation Factor

# %%
#finding variance inflation factor in each scaled column 
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values              Features
# 0     3.176269               Alcohol
# 1     1.454721            Malic acid
# 2     2.473955                   Ash
# 3     1.774677     Alcalinity of ash
# 4     1.407008             Magnesium
# 5     4.040925         Total phenols
# 6     9.763832            Flavanoids
# 7     2.170886  Nonflavanoid phenols
# 8     1.910348       Proanthocyanins
# 9     4.205276       Color intensity
# 10    1.360211                   Hue
# 11    2.625006         diluted wines
# 12    3.043773           Proline

# %% [markdown]
# Note- we can see that  vif values for all columns is in permissible limit

# %% [markdown]
# Now we have the data  balanced, so lets make a machine learning model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge

maxAccu = 0
maxRS = 0

# %%
# finding the best accuracy state


for i in range(1,96):
    x_train,x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state = i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred= lr.predict(x_test)
    acc= r2_score(y_test,pred)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS = i
        
print("max r2_score  is ", maxAccu, "at random_state", maxRS)
# Out:
# max r2_score  is  0.881676432096962 at random_state 11

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],'solver':['auto','svd','cholesky','lsqr','sag','saga','lbfgs'],'positive':[False,True],'random_state':[1,4,10,20]
      
      }
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 10,
#  'solver': 'sag'}

# %%
Model=Ridge(alpha=.05,fit_intercept=True,positive=False,random_state=1,solver='lsqr')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('r2_score:',r2_score(y_test,pred))
# Out:
# r2_score: 0.7976624637181444

# %%
import joblib

# %%
import pickle
filename='winedataset.pkl'
pickle.dump(Model,open(filename,'wb')) # saved model

# %%
import pickle

loaded_model=pickle.load(open('winedataset.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 90.32053994761013

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Model Predicted","Original"])
conclusion
# Out:
#                        0         1         2         3         4         5   \
# Model Predicted  1.703232  1.999064  0.892749  1.017867  1.832003  1.117362
# Original         2.000000  2.000000  1.000000  1.000000  2.000000  1.000000
#
#                     6         7         8         9   ...        19        20  \
# Model Predicted  2.023  1.042857  1.213777  0.885947  ...  0.957961  1.022075
# Original         2.000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
#
#                        21        22        23        24     25        26  \
# Model Predicted  1.866277  2.283353  1.276063  0.897124  1.832  0.906263
# Original         2.000000  2.000000  1.000000  1.000000  2.000  1.000000
#
#                        27        28
# Model Predicted  0.797358  1.958335
# Original         1.000000  2.000000
#
# [2 rows x 29 columns]
